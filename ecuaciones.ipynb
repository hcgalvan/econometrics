# %% [markdown]
# Sure, here's the derivation of the least squares estimator for $\beta_1$ in LaTeX:
#
# Let's start with the population regression function:
#
# \begin{equation}
# Y = \beta_0 + \beta_1 X + u
# \end{equation}
#
# The least squares estimator for $\beta_1$ is given by:
#
# $b_1 = (\bar{Y} - b_2 \bar{X})$
#
# \begin{equation}
# \hat{\beta}_1 = \frac{\sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})}{\sum_{i=1}^{n} (X_i - \bar{X})^2}
# \end{equation}
#
# To derive this, we need to minimize the sum of squared residuals:
#
# \begin{equation}
# \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^{n} (Y_i - (\hat{\beta}_0 + \hat{\beta}_1 X_i))^2
# \end{equation}
#
# Taking the partial derivative with respect to $\hat{\beta}_1$, we get:
#
# \begin{align}
# \frac{\partial}{\partial \hat{\beta}_1} \sum_{i=1}^{n} (Y_i - (\hat{\beta}_0 + \hat{\beta}_1 X_i))^2 &= -2 \sum_{i=1}^{n} (Y_i - (\hat{\beta}_0 + \hat{\beta}_1 X_i))X_i \\
# &= -2 \sum_{i=1}^{n} (Y_i X_i - \hat{\beta}_0 X_i - \hat{\beta}_1 X_i^2)
# \end{align}
#
# Setting this derivative equal to zero and solving for $\hat{\beta}_1$, we get:
#
# \begin{align}
# 0 &= -2 \sum_{i=1}^{n} (Y_i X_i - \hat{\beta}_0 X_i - \hat{\beta}_1 X_i^2) \\
# \sum_{i=1}^{n} Y_i X_i &= \hat{\beta}_0 \sum_{i=1}^{n} X_i + \hat{\beta}_1 \sum_{i=1}^{n} X_i^2 \\
# \hat{\beta}_1 &= \frac{\sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})}{\sum_{i=1}^{n} (X_i - \bar{X})^2}
# \end{align}
#
# This is the derivation of the least squares estimator for $\beta_1$ in Dougherty's "Introduction to Econometrics" 5th edition. Let me know if you have any further questions!

# %% [markdown]
# Sure, here's the derivation of the formula for the least squares estimator of $\beta_0$, which is $b_0 = \bar{Y} - b_1 \bar{X}$, in LaTeX:
#
# We start with the population regression function:
#
# \begin{equation}
# Y = \beta_0 + \beta_1 X + u
# \end{equation}
#
# The least squares estimator for $\beta_1$ is given by:
#
# \begin{equation}
# b_1 = \frac{\sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})}{\sum_{i=1}^{n} (X_i - \bar{X})^2}
# \end{equation}
#
# To derive the expression for $b_0$, we can rearrange the population regression function to solve for $\beta_0$:
#
# \begin{equation}
# Y = \beta_0 + \beta_1 X + u
# \end{equation}
#
# Taking the expected value of both sides, we get:
#
# \begin{equation}
# \mathbb{E}[Y] = \beta_0 + \beta_1 \mathbb{E}[X]
# \end{equation}
#
# Substituting the sample means, we get:
#
# \begin{equation}
# \bar{Y} = \beta_0 + \beta_1 \bar{X}
# \end{equation}
#
# Rearranging this equation, we get the expression for the least squares estimator of $\beta_0$:
#
# \begin{equation}
# b_0 = \bar{Y} - b_1 \bar{X}
# \end{equation}
#
# This is the derivation of the formula for the least squares estimator of $\beta_0$ in Dougherty's "Introduction to Econometrics" 5th edition. Let me know if you have any further questions!

# %% [markdown]
# Sure, here's the derivation of the formula for the least squares estimator of $\beta_0$, which is $b_0 = \bar{Y} - b_1 \bar{X}$, in LaTeX:
#
# We start with the population regression function:
#
# \begin{equation}
# Y = \beta_0 + \beta_1 X + u
# \end{equation}
#
# The least squares estimator for $\beta_1$ is given by:
#
# \begin{equation}
# b_1 = \frac{\sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})}{\sum_{i=1}^{n} (X_i - \bar{X})^2}
# \end{equation}
#
# To derive the expression for $b_0$, we can rearrange the population regression function to solve for $\beta_0$:
#
# \begin{equation}
# Y = \beta_0 + \beta_1 X + u
# \end{equation}
#
# Taking the expected value of both sides, we get:
#
# \begin{equation}
# \mathbb{E}[Y] = \beta_0 + \beta_1 \mathbb{E}[X]
# \end{equation}
#
# Substituting the sample means, we get:
#
# \begin{equation}
# \bar{Y} = \beta_0 + \beta_1 \bar{X}
# \end{equation}
#
# Rearranging this equation, we get the expression for the least squares estimator of $\beta_0$:
#
# \begin{equation}
# b_0 = \bar{Y} - b_1 \bar{X}
# \end{equation}
#
# This is the derivation of the formula for the least squares estimator of $\beta_0$ in Dougherty's "Introduction to Econometrics" 5th edition. Let me know if you have any further questions!
